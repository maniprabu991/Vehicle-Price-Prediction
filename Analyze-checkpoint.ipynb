# %% [markdown]
# # 1. Data Cleaning: Handling Missing Values, Outliers

# %%
import pandas as pd
import numpy as np

# %%
#Load dataset
dataset = pd.read_csv('dataset.csv')

# %%
dataset
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 0       0.6        188        2  ...         20       756  2549     9     7
# 1       0.7        136        3  ...        905      1988  2631    17     3
# 2       0.9        145        5  ...       1263      1716  2603    11     2
# 3       0.8        131        6  ...       1216      1786  2769    16     8
# 4       0.6        141        2  ...       1208      1212  1411     8     2
# ...     ...        ...      ...  ...        ...       ...   ...   ...   ...
# 1995    0.8        106        6  ...       1222      1890   668    13     4
# 1996    0.2        187        4  ...        915      1965  2032    11    10
# 1997    0.7        108        8  ...        868      1632  3057     9     1
# 1998    0.1        145        5  ...        336       670   869    18    10
# 1999    0.9        168        6  ...        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen  wifi  price_range
# 0            19        0             0     1            1
# 1             7        1             1     0            2
# 2             9        1             1     0            2
# 3            11        1             0     0            2
# 4            15        1             1     0            1
# ...         ...      ...           ...   ...          ...
# 1995         19        1             1     0            0
# 1996         16        1             1     1            2
# 1997          5        1             1     0            3
# 1998         19        1             1     1            0
# 1999          2        1             1     1            3
#
# [2000 rows x 21 columns]

# %%
# how many rows and columns
dataset.shape
# Out:
# (2000, 21)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
#  18  touch_screen   2000 non-null   int64
#  19  wifi           2000 non-null   int64
#  20  price_range    2000 non-null   int64
# dtypes: float64(2), int64(19)
# memory usage: 328.3 KB

# %%
dataset.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
dataset.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
def univariate(dataset):
    Qual=[]
    Quan=[]
    for columnName in dataset:
        #print(columnName)
        if(dataset[columnName].dtypes =='O'):
            #print('Qual')
            Qual.append(columnName)
        else:
            #print('Quan')
            Quan.append(columnName)
    return Qual,Quan

# %%
Qual,Quan = univariate(dataset)

# %%
Qual
# Out:
# []

# %%
Quan
# Out:
# ['battery_power',
#  'blue',
#  'clock_speed',
#  'dual_sim',
#  'fc',
#  'four_g',
#  'int_memory',
#  'm_dep',
#  'mobile_wt',
#  'n_cores',
#  'pc',
#  'px_height',
#  'px_width',
#  'ram',
#  'sc_h',
#  'sc_w',
#  'talk_time',
#  'three_g',
#  'touch_screen',
#  'wifi',
#  'price_range']

# %%
dataset.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# min       0.000000     2.000000     0.100000    80.000000     1.000000  ...
# 25%       0.000000    16.000000     0.200000   109.000000     3.000000  ...
# 50%       1.000000    32.000000     0.500000   141.000000     4.000000  ...
# 75%       1.000000    48.000000     0.800000   170.000000     7.000000  ...
# max       1.000000    64.000000     1.000000   200.000000     8.000000  ...
#
#          px_height     px_width          ram         sc_h         sc_w  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean    645.108000  1251.515500  2124.213000    12.306500     5.767000
# std     443.780811   432.199447  1084.732044     4.213245     4.356398
# min       0.000000   500.000000   256.000000     5.000000     0.000000
# 25%     282.750000   874.750000  1207.500000     9.000000     2.000000
# 50%     564.000000  1247.000000  2146.500000    12.000000     5.000000
# 75%     947.250000  1633.000000  3064.500000    16.000000     9.000000
# max    1960.000000  1998.000000  3998.000000    19.000000    18.000000
#
#          talk_time      three_g  touch_screen         wifi  price_range
# count  2000.000000  2000.000000   2000.000000  2000.000000  2000.000000
# mean     11.011000     0.761500      0.503000     0.507000     1.500000
# std       5.463955     0.426273      0.500116     0.500076     1.118314
# min       2.000000     0.000000      0.000000     0.000000     0.000000
# 25%       6.000000     1.000000      0.000000     0.000000     0.750000
# 50%      11.000000     1.000000      1.000000     1.000000     1.500000
# 75%      16.000000     1.000000      1.000000     1.000000     2.250000
# max      20.000000     1.000000      1.000000     1.000000     3.000000
#
# [8 rows x 21 columns]

# %%
# Step 1: Select specific columns for outlier detection
Quan_S = [
    'battery_power',
    'clock_speed',
    'fc',
    'int_memory',
    'm_dep',
    'mobile_wt',
    'n_cores',
    'pc',
    'px_height',
    'px_width',
    'ram',
    'sc_h',
    'sc_w',
    'talk_time'
]

# %%
def central_tendency_IQR(dataset, Quan_S):

    descriptive = pd.DataFrame(
        index=[
            'Mean', 'Median', 'Mode',
            'Q1:25%', 'Q2:50%', 'Q3:75%', 'Q4:100%',
            'IQR', 'Lesser IQR', 'Greater IQR',
            'min', 'max', 'kurtosis', 'skew', 'var', 'std'
        ],
        columns=Quan_S
    )

    for columnName in Quan_S:
        descriptive.loc['Mean', columnName] = dataset[columnName].mean()
        descriptive.loc['Median', columnName] = dataset[columnName].median()
        descriptive.loc['Mode', columnName] = dataset[columnName].mode()[0]

        Q1 = dataset[columnName].quantile(0.25)
        Q2 = dataset[columnName].quantile(0.50)
        Q3 = dataset[columnName].quantile(0.75)
        IQR = Q3 - Q1

        descriptive.loc['Q1:25%', columnName] = Q1
        descriptive.loc['Q2:50%', columnName] = Q2
        descriptive.loc['Q3:75%', columnName] = Q3
        descriptive.loc['Q4:100%', columnName] = dataset[columnName].max()

        descriptive.loc['IQR', columnName] = IQR
        descriptive.loc['Lesser IQR', columnName] = Q1 - 1.5 * IQR
        descriptive.loc['Greater IQR', columnName] = Q3 + 1.5 * IQR

        descriptive.loc['min', columnName] = dataset[columnName].min()
        descriptive.loc['max', columnName] = dataset[columnName].max()
        descriptive.loc['kurtosis', columnName] = dataset[columnName].kurtosis()
        descriptive.loc['skew', columnName] = dataset[columnName].skew()
        descriptive.loc['var', columnName] = dataset[columnName].var()
        descriptive.loc['std', columnName] = dataset[columnName].std()

    return descriptive

# %%
descriptive = central_tendency_IQR(dataset, Quan_S)

# %%
descriptive
# Out:
#              battery_power clock_speed         fc  int_memory     m_dep  \
# Mean             1238.5185     1.52225     4.3095     32.0465   0.50175
# Median              1226.0         1.5        3.0        32.0       0.5
# Mode                   618         0.5          0          27       0.1
# Q1:25%              851.75         0.7        1.0        16.0       0.2
# Q2:50%              1226.0         1.5        3.0        32.0       0.5
# Q3:75%             1615.25         2.2        7.0        48.0       0.8
# Q4:100%               1998         3.0         19          64       1.0
# IQR                  763.5         1.5        6.0        32.0       0.6
# Lesser IQR          -293.5       -1.55       -8.0       -32.0      -0.7
# Greater IQR         2760.5        4.45       16.0        96.0       1.7
# min                    501         0.5          0           2       0.1
# max                   1998         3.0         19          64       1.0
# kurtosis         -1.224144   -1.323417   0.277076   -1.216074 -1.274349
# skew              0.031898    0.178084   1.019811    0.057889  0.089082
# var          193088.359838    0.665863  18.848134  329.266971  0.083184
# std             439.418206    0.816004   4.341444   18.145715  0.288416
#
#                mobile_wt   n_cores         pc     px_height       px_width  \
# Mean             140.249    4.5205     9.9165       645.108      1251.5155
# Median             141.0       4.0       10.0         564.0         1247.0
# Mode                 182         4         10           347            874
# Q1:25%             109.0       3.0        5.0        282.75         874.75
# Q2:50%             141.0       4.0       10.0         564.0         1247.0
# Q3:75%             170.0       7.0       15.0        947.25         1633.0
# Q4:100%              200         8         20          1960           1998
# IQR                 61.0       4.0       10.0         664.5         758.25
# Lesser IQR          17.5      -3.0      -10.0        -714.0       -262.625
# Greater IQR        261.5      13.0       30.0        1944.0       2770.375
# min                   80         1          0             0            500
# max                  200         8         20          1960           1998
# kurtosis       -1.210376  -1.22975  -1.171499     -0.315865      -1.186005
# skew            0.006558  0.003628   0.017306      0.666271       0.014787
# var          1253.135567  5.234197  36.775916  196941.40804  186796.361941
# std            35.399655  2.287837   6.064315    443.780811     432.199447
#
#                         ram       sc_h      sc_w  talk_time
# Mean               2124.213    12.3065     5.767     11.011
# Median               2146.5       12.0       5.0       11.0
# Mode                   1229         17         1          7
# Q1:25%               1207.5        9.0       2.0        6.0
# Q2:50%               2146.5       12.0       5.0       11.0
# Q3:75%               3064.5       16.0       9.0       16.0
# Q4:100%                3998         19        18         20
# IQR                  1857.0        7.0       7.0       10.0
# Lesser IQR          -1578.0       -1.5      -8.5       -9.0
# Greater IQR          5850.0       26.5      19.5       31.0
# min                     256          5         0          2
# max                    3998         19        18         20
# kurtosis          -1.191913  -1.190791 -0.389523  -1.218591
# skew               0.006628  -0.098884  0.633787   0.009512
# var          1176643.606434  17.751433   18.9782  29.854806
# std             1084.732044   4.213245  4.356398   5.463955

# %%
def check_outliers(dataset, descriptive, Quan_S):
    lesser = []
    greater = []
    
    # Check for outliers
    for columnName in Quan_S:
        if descriptive.loc['Lesser IQR', columnName] > descriptive.loc['min', columnName]:
            lesser.append(columnName)

        if descriptive.loc['Greater IQR', columnName] < descriptive.loc['max', columnName]:
            greater.append(columnName)
    
    return lesser, greater

# %%
check_outliers(dataset, descriptive, Quan_S)
# Out:
# ([], ['fc', 'px_height'])

# %%
lesser,greater = check_outliers(dataset,descriptive, Quan_S)

# %%
lesser
# Out:
# []

# %%
greater
# Out:
# ['fc', 'px_height']

# %%
dataset[['fc', 'px_height']].describe()
# Out:
#                 fc    px_height
# count  2000.000000  2000.000000
# mean      4.309500   645.108000
# std       4.341444   443.780811
# min       0.000000     0.000000
# 25%       1.000000   282.750000
# 50%       3.000000   564.000000
# 75%       7.000000   947.250000
# max      19.000000  1960.000000

# %%
#This is NOT an outlier problem
#These values are realistic and valid

# %%
import seaborn as sns
sns.boxplot(x=dataset['fc'])
sns.boxplot(x=dataset['px_height'])
# Out:
# <Axes: xlabel='fc'>

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

df = pd.read_csv('dataset.csv')

# %%
X = df.drop('price_range', axis=1)

# %%
X_const = add_constant(X)

# %%
vif_data = pd.DataFrame()
vif_data['Feature'] = X_const.columns
vif_data['VIF'] = [
    variance_inflation_factor(X_const.values, i)
    for i in range(X_const.shape[1])
]

vif_data
# Out:
#           Feature        VIF
# 0           const  73.921098
# 1   battery_power   1.009945
# 2            blue   1.011342
# 3     clock_speed   1.006025
# 4        dual_sim   1.011555
# 5              fc   1.718987
# 6          four_g   1.528509
# 7      int_memory   1.009274
# 8           m_dep   1.006385
# 9       mobile_wt   1.004548
# 10        n_cores   1.008442
# 11             pc   1.720785
# 12      px_height   1.369052
# 13       px_width   1.362399
# 14            ram   1.008331
# 15           sc_h   1.356109
# 16           sc_w   1.353648
# 17      talk_time   1.010502
# 18        three_g   1.527367
# 19   touch_screen   1.006278
# 20           wifi   1.009100

# %%
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  int_memory  m_dep  \
# 0               842     0          2.2         0           7    0.6
# 1              1021     1          0.5         1          53    0.7
# 2               563     1          0.5         1          41    0.9
# 3               615     1          2.5         0          10    0.8
# 4              1821     1          1.2         0          44    0.6
# ...             ...   ...          ...       ...         ...    ...
# 1995            794     1          0.5         1           2    0.8
# 1996           1965     1          2.6         1          39    0.2
# 1997           1911     0          0.9         1          36    0.7
# 1998           1512     0          0.9         0          46    0.1
# 1999            510     1          2.0         1          45    0.9
#
#       mobile_wt  n_cores   ram  talk_time  touch_screen  wifi  price_range  \
# 0           188        2  2549         19             0     1            1
# 1           136        3  2631          7             1     0            2
# 2           145        5  2603          9             1     0            2
# 3           131        6  2769         11             0     0            2
# 4           141        2  1411         15             1     0            1
# ...         ...      ...   ...        ...           ...   ...          ...
# 1995        106        6   668         19             1     0            0
# 1996        187        4  2032         16             1     1            2
# 1997        108        8  3057          5             1     0            3
# 1998        145        5   869         19             1     1            0
# 1999        168        6  3919          2             1     1            3
#
#       pixel_area  screen_area  total_camera_mp  supports_3_4G
# 0          15120           63                3              0
# 1        1799140           51                6              1
# 2        2167308           22                8              1
# 3        2171776          128                9              1
# 4        1464096           16               27              1
# ...          ...          ...              ...            ...
# 1995     2309580           52               14              1
# 1996     1797975          110                3              1
# 1997     1416576            9                4              1
# 1998      225120          180                9              1
# 1999      364182           76               21              1
#
# [2000 rows x 17 columns]

# %%
# Load dataset
df = pd.read_csv('dataset.csv')

# 1️⃣ Combine display features
df['pixel_area'] = df['px_height'] * df['px_width']
df['screen_area'] = df['sc_h'] * df['sc_w']

# 2️⃣ Combine camera features
df['total_camera_mp'] = df['fc'] + df['pc']

# 3️⃣ Combine network features
df['supports_3_4G'] = df[['three_g', 'four_g']].max(axis=1)

# 4️⃣ Drop original redundant features
df.drop(['px_height', 'px_width', 'sc_h', 'sc_w', 'fc', 'pc', 'three_g', 'four_g'], axis=1, inplace=True)


df
# Out:
#       battery_power  blue  clock_speed  dual_sim  int_memory  m_dep  \
# 0               842     0          2.2         0           7    0.6
# 1              1021     1          0.5         1          53    0.7
# 2               563     1          0.5         1          41    0.9
# 3               615     1          2.5         0          10    0.8
# 4              1821     1          1.2         0          44    0.6
# ...             ...   ...          ...       ...         ...    ...
# 1995            794     1          0.5         1           2    0.8
# 1996           1965     1          2.6         1          39    0.2
# 1997           1911     0          0.9         1          36    0.7
# 1998           1512     0          0.9         0          46    0.1
# 1999            510     1          2.0         1          45    0.9
#
#       mobile_wt  n_cores   ram  talk_time  touch_screen  wifi  price_range  \
# 0           188        2  2549         19             0     1            1
# 1           136        3  2631          7             1     0            2
# 2           145        5  2603          9             1     0            2
# 3           131        6  2769         11             0     0            2
# 4           141        2  1411         15             1     0            1
# ...         ...      ...   ...        ...           ...   ...          ...
# 1995        106        6   668         19             1     0            0
# 1996        187        4  2032         16             1     1            2
# 1997        108        8  3057          5             1     0            3
# 1998        145        5   869         19             1     1            0
# 1999        168        6  3919          2             1     1            3
#
#       pixel_area  screen_area  total_camera_mp  supports_3_4G
# 0          15120           63                3              0
# 1        1799140           51                6              1
# 2        2167308           22                8              1
# 3        2171776          128                9              1
# 4        1464096           16               27              1
# ...          ...          ...              ...            ...
# 1995     2309580           52               14              1
# 1996     1797975          110                3              1
# 1997     1416576            9                4              1
# 1998      225120          180                9              1
# 1999      364182           76               21              1
#
# [2000 rows x 17 columns]

# %%
# 5️⃣ Separate numeric and binary columns (optional, for clarity)
numeric_features = ['battery_power', 'clock_speed', 'int_memory', 'm_dep', 'mobile_wt',
                    'n_cores', 'ram', 'talk_time', 'pixel_area', 'screen_area', 'total_camera_mp']
binary_features = ['blue', 'dual_sim', 'touch_screen', 'wifi', 'supports_3_4G']

# Final columns
final_columns = numeric_features + binary_features + ['price_range']
df = df[final_columns]

print(df.head())
# Out:
#    battery_power  clock_speed  int_memory  m_dep  mobile_wt  n_cores   ram  \
# 0            842          2.2           7    0.6        188        2  2549
# 1           1021          0.5          53    0.7        136        3  2631
# 2            563          0.5          41    0.9        145        5  2603
# 3            615          2.5          10    0.8        131        6  2769
# 4           1821          1.2          44    0.6        141        2  1411
#
#    talk_time  pixel_area  screen_area  total_camera_mp  blue  dual_sim  \
# 0         19       15120           63                3     0         0
# 1          7     1799140           51                6     1         1
# 2          9     2167308           22                8     1         1
# 3         11     2171776          128                9     1         0
# 4         15     1464096           16               27     1         0
#
#    touch_screen  wifi  supports_3_4G  price_range
# 0             0     1              0            1
# 1             1     0              1            2
# 2             1     0              1            2
# 3             0     0              1            2
# 4             1     0              1            1

# %%
# Save the modified dataset to a new CSV file (for example)
modified_file_path = 'finaldata.csv'
df.to_csv(modified_file_path, index=False)
